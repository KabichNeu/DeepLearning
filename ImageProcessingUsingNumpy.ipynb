# %%
import numpy as np

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from PIL import Image

# %%
pic  = Image.open('data/dog.jpeg')

# %%
pic
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1600x900 at 0x7F89695487D0>

# %%
type(pic)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
pic_arr = np.asarray(pic)

# %%
type(pic_arr)
# Out:
# numpy.ndarray

# %%
pic_arr.shape
# Out:
# (900, 1600, 3)

# %%
plt.imshow(pic_arr)

# %%
pic_red = pic_arr.copy()

# %%
pic_red.shape
# Out:
# (900, 1600, 3)

# %%
plt.imshow(pic_red[:,:,0])

# %%
plt.imshow(pic_red[:,:,0], cmap = 'gray')

# %%
plt.imshow(pic_red[:,:,1],cmap = 'gray')

# %%
plt.imshow(pic_red[:,:,2],cmap = 'gray')

# %%
pic_red[:,:,1] = 0

# %%
pic_red
# Out:
# array([[[157,   0, 174],
#         [157,   0, 174],
#         [157,   0, 174],
#         ...,
#         [ 63,   0,   8],
#         [ 63,   0,   8],
#         [ 63,   0,   8]],
#
#        [[158,   0, 174],
#         [158,   0, 174],
#         [158,   0, 174],
#         ...,
#         [ 63,   0,   8],
#         [ 63,   0,   8],
#         [ 63,   0,   8]],
#
#        [[156,   0, 172],
#         [156,   0, 172],
#         [156,   0, 172],
#         ...,
#         [ 62,   0,   7],
#         [ 62,   0,   7],
#         [ 62,   0,   7]],
#
#        ...,
#
#        [[106,   0,  42],
#         [107,   0,  43],
#         [107,   0,  45],
#         ...,
#         [123,   0,  52],
#         [122,   0,  51],
#         [121,   0,  50]],
#
#        [[107,   0,  43],
#         [109,   0,  45],
#         [108,   0,  46],
#         ...,
#         [123,   0,  52],
#         [122,   0,  51],
#         [121,   0,  50]],
#
#        [[108,   0,  44],
#         [110,   0,  46],
#         [109,   0,  47],
#         ...,
#         [123,   0,  52],
#         [122,   0,  51],
#         [122,   0,  51]]], dtype=uint8)

# %%
plt.imshow(pic_red)

# %%
pic_red[:,:,2] = 0

# %%
plt.imshow(pic_red)

# %%
pic_red.shape
# Out:
# (900, 1600, 3)

# %%
pic_red[:,:,2].shape
# Out:
# (900, 1600)
